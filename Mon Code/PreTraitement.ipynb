# %%
import pandas as p
import numpy as n

# %%
df1 = p.read_excel("spaces.xlsx")
print(df1.head())
# Out:
#   spaces Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 0     id        nom  date_ouverture  date_fermeture
# 1     71    La loge            2012             NaN
# 2    164          W            2010             NaN
# 3     81      HEKLA            2013            2017
# 4     79  Rosa Brux            2012             NaN
#
#                       Unnamed: 4             Unnamed: 5  \
# 0                        website                  email
# 1                 www.la-loge.be        info@la-loge.be
# 2               www.w-pantin.xyz    wladresse@gmail.com
# 3  www.facebook.com/heklagalerie  heklastudio@gmail.com
# 4               www.rosabrux.org   contact@rosabrux.org
#
#                            Unnamed: 6                    Unnamed: 7  \
# 0                             adresse                      horaires
# 1  Kluisstraat - rue de l’Ermitage 86                           NaN
# 2                      6 avenue Weber  Sur le temps des expositions
# 3                     50 Joseph Claes                           NaN
# 4                RUE DE L'AUTONOMIE 9                           NaN
#
#                                           Unnamed: 8  \
# 0                                       presentation
# 1                                                NaN
# 2  <p>W s&rsquo;est install&eacute; dans la banli...
# 3                                                NaN
# 4                                                NaN
#
#                                           Unnamed: 9  ... Unnamed: 26  \
# 0                                       responsables  ...        slug
# 1                                                NaN  ...     la-loge
# 2  Ana Braga, Fanny Châlot, Vincent Deniel, Judit...  ...           w
# 3                                                NaN  ...       hekla
# 4                                                NaN  ...   rosa-brux
#
#   Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0        pays       ville    latitude   longitude
# 1    Belgique   Bruxelles    50.82846   4.3656465
# 2      France      Pantin  48.9040979   2.3957386
# 3    Belgique   Bruxelles  50.8329074   4.3381126
# 4    Belgique   Bruxelles  50.8404007   4.3378064
#
#                                          Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0                                   adresse_complete  codepostal   telephone
# 1  Kluisstraat - rue de l’Ermitage 86, 1050, Brux...        1050         NaN
# 2              6 avenue Weber, 93500, Pantin, France       93500         NaN
# 3         50 Joseph Claes, 1060, Bruxelles, Belgique        1060         NaN
# 4    RUE DE L'AUTONOMIE 9, 1070, Bruxelles, Belgique        1070         NaN
#
#   Unnamed: 34 Unnamed: 35
# 0      visite     user_id
# 1         NaN         NaN
# 2         NaN           1
# 3         NaN           1
# 4         NaN         NaN
#
# [5 rows x 36 columns]

# %%
df1.head(10)
# Out:
#   spaces                Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 0     id                       nom  date_ouverture  date_fermeture
# 1     71                   La loge            2012             NaN
# 2    164                         W            2010             NaN
# 3     81                     HEKLA            2013            2017
# 4     79                 Rosa Brux            2012             NaN
# 5     83        Greylight Projects            2009             NaN
# 6     82                HECTOLITER            2009            2016
# 7     76  Artists Club Coffre-Fort            2013             NaN
# 8    198                      / 77            2015             NaN
# 9     77                    Island            2012             NaN
#
#                                 Unnamed: 4                       Unnamed: 5  \
# 0                                  website                            email
# 1                           www.la-loge.be                  info@la-loge.be
# 2                         www.w-pantin.xyz              wladresse@gmail.com
# 3            www.facebook.com/heklagalerie            heklastudio@gmail.com
# 4                         www.rosabrux.org             contact@rosabrux.org
# 5                    greylightprojects.org     office@greylightprojects.org
# 6                        www.hectoliter.be               info@hectoliter.be
# 7  www.instagram.com/artistsclubcoffrefort                              NaN
# 8                    progetto77.tumblr.com  progettosettantasette@gmail.com
# 9                      www.islandisland.be             info@islandisland.be
#
#                            Unnamed: 6                    Unnamed: 7  \
# 0                             adresse                      horaires
# 1  Kluisstraat - rue de l’Ermitage 86                           NaN
# 2                      6 avenue Weber  Sur le temps des expositions
# 3                     50 Joseph Claes                           NaN
# 4                RUE DE L'AUTONOMIE 9                           NaN
# 5                    Rue Brialmont 11                           NaN
# 6                  place du samedi 17                           NaN
# 7                        Hopstraat 63                           NaN
# 8                       Via Plinio 43                On appointment
# 9               155 chaussée de Wavre                           NaN
#
#                                           Unnamed: 8  \
# 0                                       presentation
# 1                                                NaN
# 2  <p>W s&rsquo;est install&eacute; dans la banli...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  <p>H E C T O L I T E R is a project space for ...
# 7  <p>In March 2012, Thibaut Espiau, I&scaron;tva...
# 8  <p><em>&nbsp;-English below- <br /><br /></em>...
# 9  <p>Island is a non profit art space, opened in...
#
#                                           Unnamed: 9  ...  \
# 0                                       responsables  ...
# 1                                                NaN  ...
# 2  Ana Braga, Fanny Châlot, Vincent Deniel, Judit...  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
# 6  Tine Ringelé and Nico Sall. Christophe Piette ...  ...
# 7  Thibaut Espiau, Ištvan Išt Huzjan and Grégoire...  ...
# 8                   Giulia Ratti, Alessandro Moroni.  ...
# 9                 Sébastien Bonin and Brice Guilbert  ...
#
#                 Unnamed: 26 Unnamed: 27 Unnamed: 28        Unnamed: 29  \
# 0                      slug        pays       ville           latitude
# 1                   la-loge    Belgique   Bruxelles           50.82846
# 2                         w      France      Pantin         48.9040979
# 3                     hekla    Belgique   Bruxelles         50.8329074
# 4                 rosa-brux    Belgique   Bruxelles         50.8404007
# 5        greylight-projects    Belgique   Bruxelles         50.8536207
# 6                hectoliter    Belgique   Bruxelles  50.85151560000001
# 7  artists-club-coffre-fort    Belgique   Bruxelles          50.851304
# 8                        77       Italy      Milano         45.4766129
# 9                    island    Belgique   Bruxelles         50.8355038
#
#          Unnamed: 30                                        Unnamed: 31  \
# 0          longitude                                   adresse_complete
# 1          4.3656465  Kluisstraat - rue de l’Ermitage 86, 1050, Brux...
# 2          2.3957386              6 avenue Weber, 93500, Pantin, France
# 3          4.3381126         50 Joseph Claes, 1060, Bruxelles, Belgique
# 4          4.3378064    RUE DE L'AUTONOMIE 9, 1070, Bruxelles, Belgique
# 5          4.3673498        Rue Brialmont 11, 1210, Bruxelles, Belgique
# 6           4.350256      place du samedi 17, 1000, Bruxelles, Belgique
# 7          4.3410815            Hopstraat 63, 1000, Bruxelles, Belgique
# 8  9.218095199999999                     Via Plinio 43, , Milano, Italy
# 9          4.3701134   155 chaussée de Wavre, 1050, Bruxelles, Belgique
#
#   Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35
# 0  codepostal   telephone      visite     user_id
# 1        1050         NaN         NaN         NaN
# 2       93500         NaN         NaN           1
# 3        1060         NaN         NaN           1
# 4        1070         NaN         NaN         NaN
# 5        1210         NaN         NaN           3
# 6        1000         NaN         NaN           1
# 7        1000         NaN         NaN           1
# 8         NaN         NaN         NaN           1
# 9        1050         NaN         NaN           1
#
# [10 rows x 36 columns]

# %%
colonnes_vides = df1.isna().sum()
print(colonnes_vides)
# Out:
# spaces           0
# Unnamed: 1       0
# Unnamed: 2       0
# Unnamed: 3     211
# Unnamed: 4      49
# Unnamed: 5      52
# Unnamed: 6       0
# Unnamed: 7     188
# Unnamed: 8      19
# Unnamed: 9      84
# Unnamed: 10    223
# Unnamed: 11    264
# Unnamed: 12      2
# Unnamed: 13      2
# Unnamed: 14      2
# Unnamed: 15      2
# Unnamed: 16      2
# Unnamed: 17      2
# Unnamed: 18      2
# Unnamed: 19      2
# Unnamed: 20      2
# Unnamed: 21    310
# Unnamed: 22    324
# Unnamed: 23    286
# Unnamed: 24      0
# Unnamed: 25      0
# Unnamed: 26      0
# Unnamed: 27      0
# Unnamed: 28      0
# Unnamed: 29      0
# Unnamed: 30      0
# Unnamed: 31      0
# Unnamed: 32    105
# Unnamed: 33    323
# Unnamed: 34    335
# Unnamed: 35      4
# dtype: int64

# %%
from bs4 import BeautifulSoup
def enlever_balises_html(texte):
    if isinstance(texte, str):
        return BeautifulSoup(texte, 'html.parser').get_text()
    return texte
df1 = df1.applymap(enlever_balises_html)
df1.to_csv('../../../Donnees/spacesnew.csv', index=False)
# Out:
# C:\Users\Noah\AppData\Local\Temp\ipykernel_14560\3054509210.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1 = df1.applymap(enlever_balises_html)
# C:\Users\Noah\AppData\Local\Temp\ipykernel_14560\3054509210.py:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(texte, 'html.parser').get_text()
# C:\Users\Noah\AppData\Local\Temp\ipykernel_14560\3054509210.py:4: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   return BeautifulSoup(texte, 'html.parser').get_text()

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
df= pd.read_excel('spacestri.xlsx')
print(df.head())

# %%
import docx  # python-docx est importé en tant que 'docx'
import pandas as pd
import re  # Pour utiliser les expressions régulières

def extraire_donnees_depuis_docx(chemin_docx):
    document = docx.Document(chemin_docx)
    
    donnees = []
    nom_actuel = None
    question_actuelle = None
    questions_reponses = {}
    
    for paragraphe in document.paragraphs:
        texte = paragraphe.text.strip()
        
        if paragraphe.style.name.startswith('Heading'):  # Suppose que le nom est un titre
            if nom_actuel and questions_reponses:
                donnees.append({'nom': nom_actuel, 'questions_reponses': questions_reponses})
            nom_actuel = texte
            questions_reponses = {}
            question_actuelle = None
        
        elif texte.startswith("Q"):  # Suppose que les questions commencent par "Q"
            question_actuelle = texte
            questions_reponses[question_actuelle] = ''
        
        elif question_actuelle:  # Suppose que tout texte après une question est une réponse
            questions_reponses[question_actuelle] += ' ' + texte
    
    if nom_actuel and questions_reponses:
        donnees.append({'nom': nom_actuel, 'questions_reponses': questions_reponses})
    
    return donnees

def extraire_nom_et_sites(texte):
    # Regex améliorée pour capturer des noms composés et gérer mieux les titres
    match_nom = re.search(r'([A-Z][a-zéèêîï]+(?:\s[A-Z][a-zéèêîï]+)+)', texte)
    nom_responsable = match_nom.group(0) if match_nom else 'Nom non trouvé'
    
    # Regex pour capturer tous les sites web dans le texte (peut en avoir plusieurs)
    sites_web = re.findall(r'(www\.[\w.-]+|@\w+)', texte)
    if not sites_web:
        sites_web = ['Site web non trouvé']
    
    return nom_responsable, sites_web

# Charger le fichier Excel avec pandas
df = pd.read_excel('spacestri.xlsx')

# Ajouter les colonnes pour les questions et réponses dans le DataFrame
df['question1'] = ''
df['réponse1'] = ''
df['question2'] = ''
df['réponse2'] = ''
df['nom_responsable'] = ''
df['site_web'] = ''

# Vérifier la dernière valeur d'ID dans le DataFrame
dernier_id = df['id'].max() if 'id' in df.columns else 0  # Si la colonne 'id' existe, on prend sa valeur max, sinon on commence à 0

# Parcourir les données extraites du DOCX
for entree in donnees_extraites:
    nom = entree['nom']
    questions = list(entree['questions_reponses'].keys())
    reponses = list(entree['questions_reponses'].values())
    
    # Si le nom est dans le DataFrame, on remplit les colonnes correspondantes
    if nom in df['nom'].values:
        df.loc[df['nom'] == nom, 'question1'] = questions[0] if len(questions) > 0 else ''
        df.loc[df['nom'] == nom, 'réponse1'] = reponses[0] if len(reponses) > 0 else ''
        df.loc[df['nom'] == nom, 'question2'] = questions[1] if len(questions) > 1 else ''
        df.loc[df['nom'] == nom, 'réponse2'] = reponses[1] if len(reponses) > 1 else ''
        
        # Extraire le nom du responsable et les sites web à partir de la réponse 2
        nom_responsable, sites_web = extraire_nom_et_sites(reponses[1] if len(reponses) > 1 else '')
        
        # Afficher pour vérification
        print(f"Nom : {nom}")
        print(f"Nom du responsable : {nom_responsable}")
        print(f"Sites web : {', '.join(sites_web)}\n")
        
        df.loc[df['nom'] == nom, 'nom_responsable'] = nom_responsable
        df.loc[df['nom'] == nom, 'site_web'] = ', '.join(sites_web)
    
    # Si le nom n'est pas dans le DataFrame, on ajoute une nouvelle ligne
    else:
        dernier_id += 1  # Incrémentation de l'ID
        nom_responsable, sites_web = extraire_nom_et_sites(reponses[1] if len(reponses) > 1 else '')
        
        # Afficher pour vérification
        print(f"Nom : {nom}")
        print(f"Nom du responsable : {nom_responsable}")
        print(f"Sites web : {', '.join(sites_web)}\n")
        
        nouvelle_ligne = pd.DataFrame({
            'id': [dernier_id],
            'nom': [nom],
            'question1': [questions[0] if len(questions) > 0 else ''],
            'réponse1': [reponses[0] if len(reponses) > 0 else ''],
            'question2': [questions[1] if len(questions) > 1 else ''],
            'réponse2': [reponses[1] if len(reponses) > 1 else ''],
            'nom_responsable': [nom_responsable],
            'site_web': [', '.join(sites_web)]
        })
        df = pd.concat([df, nouvelle_ligne], ignore_index=True)

# Sauvegarder le DataFrame mis à jour dans un fichier Excel ou CSV
df.to_excel('fichier_mis_a_jour.xlsx', index=False)
print("Mise à jour du fichier Excel terminée et sauvegardée dans 'fichier_mis_a_jour.xlsx'")
